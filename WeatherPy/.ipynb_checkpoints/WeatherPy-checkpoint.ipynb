# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 606

# %% [markdown]
# ## Perform API Calls

# %%
url = "http://api.openweathermap.org/data/2.5/forecast?id=524901&APPID="
target_url = url + weather_api_key
target_url
# Out:
# 'http://api.openweathermap.org/data/2.5/forecast?id=524901&APPID=962f47973599f1fb3469459756f56f45'

# %%
import json

weather_response = requests.get(target_url)
weather_json = weather_response.json()
print(json.dumps(weather_json, indent=4, sort_keys=True))
# Out:
# {
#     "city": {
#         "coord": {
#             "lat": 55.7522,
#             "lon": 37.6156
#         },
#         "country": "RU",
#         "id": 524901,
#         "name": "Moscow",
#         "sunrise": 1571544560,
#         "sunset": 1571581150,
#         "timezone": 10800
#     },
#     "cnt": 40,
#     "cod": "200",
#     "list": [
#         {
#             "clouds": {
#                 "all": 95
#             },
#             "dt": 1571594400,
#             "dt_txt": "2019-10-20 18:00:00",
#             "main": {
#                 "grnd_level": 998.09,
#                 "humidity": 88,
#                 "pressure": 1020.58,
#                 "sea_level": 1020.58,
#                 "temp": 287.98,
#                 "temp_kf": 2.84,
#                 "temp_max": 287.98,
#                 "temp_min": 285.143
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 216.345,
#                 "speed": 2.36
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1571605200,
#             "dt_txt": "2019-10-20 21:00:00",
#             "main": {
#                 "grnd_level": 997.63,
#                 "humidity": 87,
#                 "pressure": 1020.28,
#                 "sea_level": 1020.28,
#                 "temp": 286.97,
#                 "temp_kf": 2.13,
#                 "temp_max": 286.97,
#                 "temp_min": 284.839
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 214.859,
#                 "speed": 2.64
#             }
#         },
#         {
#             "clouds": {
#                 "all": 85
#             },
#             "dt": 1571616000,
#             "dt_txt": "2019-10-21 00:00:00",
#             "main": {
#                 "grnd_level": 997.41,
#                 "humidity": 88,
#                 "pressure": 1020.13,
#                 "sea_level": 1020.13,
#                 "temp": 285.75,
#                 "temp_kf": 1.42,
#                 "temp_max": 285.75,
#                 "temp_min": 284.335
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 210.618,
#                 "speed": 3.18
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1571626800,
#             "dt_txt": "2019-10-21 03:00:00",
#             "main": {
#                 "grnd_level": 995.39,
#                 "humidity": 86,
#                 "pressure": 1018.24,
#                 "sea_level": 1018.24,
#                 "temp": 284.8,
#                 "temp_kf": 0.71,
#                 "temp_max": 284.8,
#                 "temp_min": 284.093
#             },
#             "rain": {
#                 "3h": 0.062
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10n",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 208.227,
#                 "speed": 3.73
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1571637600,
#             "dt_txt": "2019-10-21 06:00:00",
#             "main": {
#                 "grnd_level": 994.93,
#                 "humidity": 82,
#                 "pressure": 1017.79,
#                 "sea_level": 1017.79,
#                 "temp": 284.304,
#                 "temp_kf": 0,
#                 "temp_max": 284.304,
#                 "temp_min": 284.304
#             },
#             "rain": {},
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 224.594,
#                 "speed": 5.09
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1571648400,
#             "dt_txt": "2019-10-21 09:00:00",
#             "main": {
#                 "grnd_level": 994.1,
#                 "humidity": 75,
#                 "pressure": 1016.4,
#                 "sea_level": 1016.4,
#                 "temp": 286.987,
#                 "temp_kf": 0,
#                 "temp_max": 286.987,
#                 "temp_min": 286.987
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 241.6,
#                 "speed": 6.27
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1571659200,
#             "dt_txt": "2019-10-21 12:00:00",
#             "main": {
#                 "grnd_level": 994.01,
#                 "humidity": 75,
#                 "pressure": 1016.34,
#                 "sea_level": 1016.34,
#                 "temp": 287.859,
#                 "temp_kf": 0,
#                 "temp_max": 287.859,
#                 "temp_min": 287.859
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 258.717,
#                 "speed": 5.75
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1571670000,
#             "dt_txt": "2019-10-21 15:00:00",
#             "main": {
#                 "grnd_level": 995.06,
#                 "humidity": 86,
#                 "pressure": 1017.29,
#                 "sea_level": 1017.29,
#                 "temp": 283.899,
#                 "temp_kf": 0,
#                 "temp_max": 283.899,
#                 "temp_min": 283.899
#             },
#             "rain": {
#                 "3h": 2.812
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10n",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 309.427,
#                 "speed": 3.9
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1571680800,
#             "dt_txt": "2019-10-21 18:00:00",
#             "main": {
#                 "grnd_level": 996.48,
#                 "humidity": 88,
#                 "pressure": 1019.09,
#                 "sea_level": 1019.09,
#                 "temp": 282.957,
#                 "temp_kf": 0,
#                 "temp_max": 282.957,
#                 "temp_min": 282.957
#             },
#             "rain": {
#                 "3h": 0.688
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10n",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 295.119,
#                 "speed": 3.69
#             }
#         },
#         {
#             "clouds": {
#                 "all": 1
#             },
#             "dt": 1571691600,
#             "dt_txt": "2019-10-21 21:00:00",
#             "main": {
#                 "grnd_level": 997.39,
#                 "humidity": 93,
#                 "pressure": 1020.33,
#                 "sea_level": 1020.33,
#                 "temp": 281.698,
#                 "temp_kf": 0,
#                 "temp_max": 281.698,
#                 "temp_min": 281.698
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01n",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 301.831,
#                 "speed": 3.62
#             }
#         },
#         {
#             "clouds": {
#                 "all": 5
#             },
#             "dt": 1571702400,
#             "dt_txt": "2019-10-22 00:00:00",
#             "main": {
#                 "grnd_level": 999.32,
#                 "humidity": 94,
#                 "pressure": 1022.59,
#                 "sea_level": 1022.59,
#                 "temp": 280.174,
#                 "temp_kf": 0,
#                 "temp_max": 280.174,
#                 "temp_min": 280.174
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01n",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 315.22,
#                 "speed": 2.58
#             }
#         },
#         {
#             "clouds": {
#                 "all": 19
#             },
#             "dt": 1571713200,
#             "dt_txt": "2019-10-22 03:00:00",
#             "main": {
#                 "grnd_level": 1000.47,
#                 "humidity": 95,
#                 "pressure": 1023.79,
#                 "sea_level": 1023.79,
#                 "temp": 279.254,
#                 "temp_kf": 0,
#                 "temp_max": 279.254,
#                 "temp_min": 279.254
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "few clouds",
#                     "icon": "02n",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 326.875,
#                 "speed": 2.25
#             }
#         },
#         {
#             "clouds": {
#                 "all": 59
#             },
#             "dt": 1571724000,
#             "dt_txt": "2019-10-22 06:00:00",
#             "main": {
#                 "grnd_level": 1001.72,
#                 "humidity": 90,
#                 "pressure": 1025.15,
#                 "sea_level": 1025.15,
#                 "temp": 280.556,
#                 "temp_kf": 0,
#                 "temp_max": 280.556,
#                 "temp_min": 280.556
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 314.311,
#                 "speed": 1.35
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1571734800,
#             "dt_txt": "2019-10-22 09:00:00",
#             "main": {
#                 "grnd_level": 1002.62,
#                 "humidity": 74,
#                 "pressure": 1025.64,
#                 "sea_level": 1025.64,
#                 "temp": 282.05,
#                 "temp_kf": 0,
#                 "temp_max": 282.05,
#                 "temp_min": 282.05
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 301.242,
#                 "speed": 2.16
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1571745600,
#             "dt_txt": "2019-10-22 12:00:00",
#             "main": {
#                 "grnd_level": 1002.22,
#                 "humidity": 74,
#                 "pressure": 1025.16,
#                 "sea_level": 1025.16,
#                 "temp": 282.16,
#                 "temp_kf": 0,
#                 "temp_max": 282.16,
#                 "temp_min": 282.16
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 263.871,
#                 "speed": 2.15
#             }
#         },
#         {
#             "clouds": {
#                 "all": 49
#             },
#             "dt": 1571756400,
#             "dt_txt": "2019-10-22 15:00:00",
#             "main": {
#                 "grnd_level": 1001.78,
#                 "humidity": 85,
#                 "pressure": 1024.76,
#                 "sea_level": 1024.76,
#                 "temp": 279.994,
#                 "temp_kf": 0,
#                 "temp_max": 279.994,
#                 "temp_min": 279.994
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03n",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 240.01,
#                 "speed": 2.43
#             }
#         },
#         {
#             "clouds": {
#                 "all": 50
#             },
#             "dt": 1571767200,
#             "dt_txt": "2019-10-22 18:00:00",
#             "main": {
#                 "grnd_level": 1000.72,
#                 "humidity": 86,
#                 "pressure": 1023.73,
#                 "sea_level": 1023.73,
#                 "temp": 279.825,
#                 "temp_kf": 0,
#                 "temp_max": 279.825,
#                 "temp_min": 279.825
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03n",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 212.552,
#                 "speed": 3.49
#             }
#         },
#         {
#             "clouds": {
#                 "all": 77
#             },
#             "dt": 1571778000,
#             "dt_txt": "2019-10-22 21:00:00",
#             "main": {
#                 "grnd_level": 998.82,
#                 "humidity": 80,
#                 "pressure": 1021.58,
#                 "sea_level": 1021.58,
#                 "temp": 280.733,
#                 "temp_kf": 0,
#                 "temp_max": 280.733,
#                 "temp_min": 280.733
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04n",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 228.459,
#                 "speed": 3.7
#             }
#         },
#         {
#             "clouds": {
#                 "all": 73
#             },
#             "dt": 1571788800,
#             "dt_txt": "2019-10-23 00:00:00",
#             "main": {
#                 "grnd_level": 997.29,
#                 "humidity": 79,
#                 "pressure": 1020.3,
#                 "sea_level": 1020.3,
#                 "temp": 281.198,
#                 "temp_kf": 0,
#                 "temp_max": 281.198,
#                 "temp_min": 281.198
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04n",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 228.541,
#                 "speed": 4.89
#             }
#         },
#         {
#             "clouds": {
#                 "all": 38
#             },
#             "dt": 1571799600,
#             "dt_txt": "2019-10-23 03:00:00",
#             "main": {
#                 "grnd_level": 996.19,
#                 "humidity": 87,
#                 "pressure": 1018.8,
#                 "sea_level": 1018.8,
#                 "temp": 281.291,
#                 "temp_kf": 0,
#                 "temp_max": 281.291,
#                 "temp_min": 281.291
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03n",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 238.517,
#                 "speed": 5.14
#             }
#         },
#         {
#             "clouds": {
#                 "all": 52
#             },
#             "dt": 1571810400,
#             "dt_txt": "2019-10-23 06:00:00",
#             "main": {
#                 "grnd_level": 994.77,
#                 "humidity": 89,
#                 "pressure": 1017.75,
#                 "sea_level": 1017.75,
#                 "temp": 282.941,
#                 "temp_kf": 0,
#                 "temp_max": 282.941,
#                 "temp_min": 282.941
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 235.387,
#                 "speed": 6.55
#             }
#         },
#         {
#             "clouds": {
#                 "all": 32
#             },
#             "dt": 1571821200,
#             "dt_txt": "2019-10-23 09:00:00",
#             "main": {
#                 "grnd_level": 994.74,
#                 "humidity": 79,
#                 "pressure": 1017.18,
#                 "sea_level": 1017.18,
#                 "temp": 286.5,
#                 "temp_kf": 0,
#                 "temp_max": 286.5,
#                 "temp_min": 286.5
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03d",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 259.973,
#                 "speed": 4.79
#             }
#         },
#         {
#             "clouds": {
#                 "all": 61
#             },
#             "dt": 1571832000,
#             "dt_txt": "2019-10-23 12:00:00",
#             "main": {
#                 "grnd_level": 994.72,
#                 "humidity": 81,
#                 "pressure": 1017.05,
#                 "sea_level": 1017.05,
#                 "temp": 286.605,
#                 "temp_kf": 0,
#                 "temp_max": 286.605,
#                 "temp_min": 286.605
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 265.468,
#                 "speed": 4.11
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1571842800,
#             "dt_txt": "2019-10-23 15:00:00",
#             "main": {
#                 "grnd_level": 994.72,
#                 "humidity": 87,
#                 "pressure": 1017.4,
#                 "sea_level": 1017.4,
#                 "temp": 285.503,
#                 "temp_kf": 0,
#                 "temp_max": 285.503,
#                 "temp_min": 285.503
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 248.622,
#                 "speed": 2.69
#             }
#         },
#         {
#             "clouds": {
#                 "all": 93
#             },
#             "dt": 1571853600,
#             "dt_txt": "2019-10-23 18:00:00",
#             "main": {
#                 "grnd_level": 995.35,
#                 "humidity": 93,
#                 "pressure": 1018.01,
#                 "sea_level": 1018.01,
#                 "temp": 284.391,
#                 "temp_kf": 0,
#                 "temp_max": 284.391,
#                 "temp_min": 284.391
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 291.883,
#                 "speed": 1.69
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1571864400,
#             "dt_txt": "2019-10-23 21:00:00",
#             "main": {
#                 "grnd_level": 995.49,
#                 "humidity": 90,
#                 "pressure": 1018.03,
#                 "sea_level": 1018.03,
#                 "temp": 283.975,
#                 "temp_kf": 0,
#                 "temp_max": 283.975,
#                 "temp_min": 283.975
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 1.815,
#                 "speed": 1.2
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1571875200,
#             "dt_txt": "2019-10-24 00:00:00",
#             "main": {
#                 "grnd_level": 996.36,
#                 "humidity": 87,
#                 "pressure": 1018.86,
#                 "sea_level": 1018.86,
#                 "temp": 283.488,
#                 "temp_kf": 0,
#                 "temp_max": 283.488,
#                 "temp_min": 283.488
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 13.46,
#                 "speed": 1.18
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1571886000,
#             "dt_txt": "2019-10-24 03:00:00",
#             "main": {
#                 "grnd_level": 996.59,
#                 "humidity": 85,
#                 "pressure": 1019.28,
#                 "sea_level": 1019.28,
#                 "temp": 283.074,
#                 "temp_kf": 0,
#                 "temp_max": 283.074,
#                 "temp_min": 283.074
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 45.133,
#                 "speed": 1.22
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1571896800,
#             "dt_txt": "2019-10-24 06:00:00",
#             "main": {
#                 "grnd_level": 997.17,
#                 "humidity": 81,
#                 "pressure": 1019.89,
#                 "sea_level": 1019.89,
#                 "temp": 283.215,
#                 "temp_kf": 0,
#                 "temp_max": 283.215,
#                 "temp_min": 283.215
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 4.247,
#                 "speed": 1.34
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1571907600,
#             "dt_txt": "2019-10-24 09:00:00",
#             "main": {
#                 "grnd_level": 997.72,
#                 "humidity": 77,
#                 "pressure": 1020.4,
#                 "sea_level": 1020.4,
#                 "temp": 283.672,
#                 "temp_kf": 0,
#                 "temp_max": 283.672,
#                 "temp_min": 283.672
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 40.354,
#                 "speed": 0.83
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1571918400,
#             "dt_txt": "2019-10-24 12:00:00",
#             "main": {
#                 "grnd_level": 998.04,
#                 "humidity": 71,
#                 "pressure": 1020.71,
#                 "sea_level": 1020.71,
#                 "temp": 284.575,
#                 "temp_kf": 0,
#                 "temp_max": 284.575,
#                 "temp_min": 284.575
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 308.357,
#                 "speed": 0.53
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1571929200,
#             "dt_txt": "2019-10-24 15:00:00",
#             "main": {
#                 "grnd_level": 998.21,
#                 "humidity": 82,
#                 "pressure": 1021.03,
#                 "sea_level": 1021.03,
#                 "temp": 282.508,
#                 "temp_kf": 0,
#                 "temp_max": 282.508,
#                 "temp_min": 282.508
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 345.348,
#                 "speed": 0.54
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1571940000,
#             "dt_txt": "2019-10-24 18:00:00",
#             "main": {
#                 "grnd_level": 999.12,
#                 "humidity": 85,
#                 "pressure": 1022.02,
#                 "sea_level": 1022.02,
#                 "temp": 281.556,
#                 "temp_kf": 0,
#                 "temp_max": 281.556,
#                 "temp_min": 281.556
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 39.618,
#                 "speed": 0.59
#             }
#         },
#         {
#             "clouds": {
#                 "all": 46
#             },
#             "dt": 1571950800,
#             "dt_txt": "2019-10-24 21:00:00",
#             "main": {
#                 "grnd_level": 999.24,
#                 "humidity": 89,
#                 "pressure": 1022.12,
#                 "sea_level": 1022.12,
#                 "temp": 280.535,
#                 "temp_kf": 0,
#                 "temp_max": 280.535,
#                 "temp_min": 280.535
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03n",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 307.106,
#                 "speed": 0.44
#             }
#         },
#         {
#             "clouds": {
#                 "all": 57
#             },
#             "dt": 1571961600,
#             "dt_txt": "2019-10-25 00:00:00",
#             "main": {
#                 "grnd_level": 999.65,
#                 "humidity": 90,
#                 "pressure": 1022.63,
#                 "sea_level": 1022.63,
#                 "temp": 279.956,
#                 "temp_kf": 0,
#                 "temp_max": 279.956,
#                 "temp_min": 279.956
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04n",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 304.681,
#                 "speed": 0.77
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1571972400,
#             "dt_txt": "2019-10-25 03:00:00",
#             "main": {
#                 "grnd_level": 999.56,
#                 "humidity": 90,
#                 "pressure": 1022.64,
#                 "sea_level": 1022.64,
#                 "temp": 280.764,
#                 "temp_kf": 0,
#                 "temp_max": 280.764,
#                 "temp_min": 280.764
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 148.772,
#                 "speed": 0.45
#             }
#         },
#         {
#             "clouds": {
#                 "all": 93
#             },
#             "dt": 1571983200,
#             "dt_txt": "2019-10-25 06:00:00",
#             "main": {
#                 "grnd_level": 999.75,
#                 "humidity": 88,
#                 "pressure": 1022.71,
#                 "sea_level": 1022.71,
#                 "temp": 281.23,
#                 "temp_kf": 0,
#                 "temp_max": 281.23,
#                 "temp_min": 281.23
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 156.43,
#                 "speed": 1.22
#             }
#         },
#         {
#             "clouds": {
#                 "all": 86
#             },
#             "dt": 1571994000,
#             "dt_txt": "2019-10-25 09:00:00",
#             "main": {
#                 "grnd_level": 999.78,
#                 "humidity": 78,
#                 "pressure": 1022.53,
#                 "sea_level": 1022.53,
#                 "temp": 284.66,
#                 "temp_kf": 0,
#                 "temp_max": 284.66,
#                 "temp_min": 284.66
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 168.862,
#                 "speed": 2.41
#             }
#         },
#         {
#             "clouds": {
#                 "all": 82
#             },
#             "dt": 1572004800,
#             "dt_txt": "2019-10-25 12:00:00",
#             "main": {
#                 "grnd_level": 998.65,
#                 "humidity": 81,
#                 "pressure": 1021.33,
#                 "sea_level": 1021.33,
#                 "temp": 286.094,
#                 "temp_kf": 0,
#                 "temp_max": 286.094,
#                 "temp_min": 286.094
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 175.75,
#                 "speed": 2.83
#             }
#         },
#         {
#             "clouds": {
#                 "all": 96
#             },
#             "dt": 1572015600,
#             "dt_txt": "2019-10-25 15:00:00",
#             "main": {
#                 "grnd_level": 997.79,
#                 "humidity": 88,
#                 "pressure": 1020.6,
#                 "sea_level": 1020.6,
#                 "temp": 284.901,
#                 "temp_kf": 0,
#                 "temp_max": 284.901,
#                 "temp_min": 284.901
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 196.36,
#                 "speed": 2.75
#             }
#         }
#     ],
#     "message": 0.0066
# }

# %%
# Create lists 
city_name = []
lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

# %%
count = 0

for city in cities:
    weather_response = requests.get(target_url + "&q=" + city + "&units=Imperial")
    weather_json = weather_response.json()
    try:
        city_name.append(weather_json['city']['name'])
        cloudiness.append(weather_json['list'][0]['clouds']['all'])
        country.append(weather_json['city']['country'])
        date.append(weather_json['list'][0]['dt'])
        humidity.append(weather_json['list'][0]['main']['humidity'])
        lat.append(weather_json['city']['coord']['lat'])
        lng.append(weather_json['city']['coord']['lon'])
        max_temp.append(weather_json['list'][0]['main']['temp_max'])
        wind_speed.append(weather_json['list'][0]['wind']['speed'])
        count = count + 1
        print(f"Processing record {count} of Set 1 | {city}")
    except:
        print("Record not found") 
        pass
    print("I made it through the gauntlet. The message survived!")
# Out:
# Processing record 1 of Set 1 | hermanus
# I made it through the gauntlet. The message survived!
# Processing record 2 of Set 1 | brookhaven
# I made it through the gauntlet. The message survived!
# Processing record 3 of Set 1 | tuktoyaktuk
# I made it through the gauntlet. The message survived!
# Processing record 4 of Set 1 | nome
# I made it through the gauntlet. The message survived!
# Processing record 5 of Set 1 | hithadhoo
# I made it through the gauntlet. The message survived!
# Processing record 6 of Set 1 | punta arenas
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 7 of Set 1 | lianyuan
# I made it through the gauntlet. The message survived!
# Processing record 8 of Set 1 | puerto ayora
# I made it through the gauntlet. The message survived!
# Processing record 9 of Set 1 | saskylakh
# I made it through the gauntlet. The message survived!
# Processing record 10 of Set 1 | souillac
# I made it through the gauntlet. The message survived!
# Processing record 11 of Set 1 | gamba
# I made it through the gauntlet. The message survived!
# Processing record 12 of Set 1 | rikitea
# I made it through the gauntlet. The message survived!
# Processing record 13 of Set 1 | butaritari
# I made it through the gauntlet. The message survived!
# Processing record 14 of Set 1 | korem
# I made it through the gauntlet. The message survived!
# Processing record 15 of Set 1 | bluff
# I made it through the gauntlet. The message survived!
# Processing record 16 of Set 1 | bilibino
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 17 of Set 1 | sur
# I made it through the gauntlet. The message survived!
# Processing record 18 of Set 1 | ushuaia
# I made it through the gauntlet. The message survived!
# Processing record 19 of Set 1 | lagoa
# I made it through the gauntlet. The message survived!
# Processing record 20 of Set 1 | hilton head island
# I made it through the gauntlet. The message survived!
# Processing record 21 of Set 1 | pisco
# I made it through the gauntlet. The message survived!
# Processing record 22 of Set 1 | luanda
# I made it through the gauntlet. The message survived!
# Processing record 23 of Set 1 | karratha
# I made it through the gauntlet. The message survived!
# Processing record 24 of Set 1 | sao borja
# I made it through the gauntlet. The message survived!
# Processing record 25 of Set 1 | upernavik
# I made it through the gauntlet. The message survived!
# Processing record 26 of Set 1 | nikolskoye
# I made it through the gauntlet. The message survived!
# Processing record 27 of Set 1 | tasiilaq
# I made it through the gauntlet. The message survived!
# Processing record 28 of Set 1 | mataura
# I made it through the gauntlet. The message survived!
# Processing record 29 of Set 1 | bonfim
# I made it through the gauntlet. The message survived!
# Processing record 30 of Set 1 | cape town
# I made it through the gauntlet. The message survived!
# Processing record 31 of Set 1 | carnarvon
# I made it through the gauntlet. The message survived!
# Processing record 32 of Set 1 | saint george
# I made it through the gauntlet. The message survived!
# Processing record 33 of Set 1 | baghdad
# I made it through the gauntlet. The message survived!
# Processing record 34 of Set 1 | wanxian
# I made it through the gauntlet. The message survived!
# Processing record 35 of Set 1 | villa guerrero
# I made it through the gauntlet. The message survived!
# Processing record 36 of Set 1 | kodiak
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 37 of Set 1 | yar-sale
# I made it through the gauntlet. The message survived!
# Processing record 38 of Set 1 | avarua
# I made it through the gauntlet. The message survived!
# Processing record 39 of Set 1 | praia da vitoria
# I made it through the gauntlet. The message survived!
# Processing record 40 of Set 1 | ancud
# I made it through the gauntlet. The message survived!
# Processing record 41 of Set 1 | machala
# I made it through the gauntlet. The message survived!
# Processing record 42 of Set 1 | sterling
# I made it through the gauntlet. The message survived!
# Processing record 43 of Set 1 | port elizabeth
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 44 of Set 1 | maxixe
# I made it through the gauntlet. The message survived!
# Processing record 45 of Set 1 | bahia honda
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 46 of Set 1 | new norfolk
# I made it through the gauntlet. The message survived!
# Processing record 47 of Set 1 | manggar
# I made it through the gauntlet. The message survived!
# Processing record 48 of Set 1 | manta
# I made it through the gauntlet. The message survived!
# Processing record 49 of Set 1 | thompson
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 50 of Set 1 | kapaa
# I made it through the gauntlet. The message survived!
# Processing record 51 of Set 1 | westport
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 52 of Set 1 | sioux lookout
# I made it through the gauntlet. The message survived!
# Processing record 53 of Set 1 | tuatapere
# I made it through the gauntlet. The message survived!
# Processing record 54 of Set 1 | banda aceh
# I made it through the gauntlet. The message survived!
# Processing record 55 of Set 1 | chumikan
# I made it through the gauntlet. The message survived!
# Processing record 56 of Set 1 | haines junction
# I made it through the gauntlet. The message survived!
# Processing record 57 of Set 1 | kindu
# I made it through the gauntlet. The message survived!
# Processing record 58 of Set 1 | gouyave
# I made it through the gauntlet. The message survived!
# Processing record 59 of Set 1 | port alfred
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 60 of Set 1 | east london
# I made it through the gauntlet. The message survived!
# Processing record 61 of Set 1 | broome
# I made it through the gauntlet. The message survived!
# Processing record 62 of Set 1 | manzhouli
# I made it through the gauntlet. The message survived!
# Processing record 63 of Set 1 | arraial do cabo
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 64 of Set 1 | progreso
# I made it through the gauntlet. The message survived!
# Processing record 65 of Set 1 | albany
# I made it through the gauntlet. The message survived!
# Processing record 66 of Set 1 | iqaluit
# I made it through the gauntlet. The message survived!
# Processing record 67 of Set 1 | saldanha
# I made it through the gauntlet. The message survived!
# Processing record 68 of Set 1 | agadir
# I made it through the gauntlet. The message survived!
# Processing record 69 of Set 1 | zelenoborsk
# I made it through the gauntlet. The message survived!
# Processing record 70 of Set 1 | castro
# I made it through the gauntlet. The message survived!
# Processing record 71 of Set 1 | katsuura
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 72 of Set 1 | tautira
# I made it through the gauntlet. The message survived!
# Processing record 73 of Set 1 | cherskiy
# I made it through the gauntlet. The message survived!
# Processing record 74 of Set 1 | esperance
# I made it through the gauntlet. The message survived!
# Processing record 75 of Set 1 | jamestown
# I made it through the gauntlet. The message survived!
# Processing record 76 of Set 1 | rio claro
# I made it through the gauntlet. The message survived!
# Processing record 77 of Set 1 | qaanaaq
# I made it through the gauntlet. The message survived!
# Processing record 78 of Set 1 | kahului
# I made it through the gauntlet. The message survived!
# Processing record 79 of Set 1 | oyek
# I made it through the gauntlet. The message survived!
# Processing record 80 of Set 1 | cayenne
# I made it through the gauntlet. The message survived!
# Processing record 81 of Set 1 | bolobo
# I made it through the gauntlet. The message survived!
# Processing record 82 of Set 1 | petropavlovsk-kamchatskiy
# I made it through the gauntlet. The message survived!
# Processing record 83 of Set 1 | zhuanghe
# I made it through the gauntlet. The message survived!
# Processing record 84 of Set 1 | nouadhibou
# I made it through the gauntlet. The message survived!
# Processing record 85 of Set 1 | severo-kurilsk
# I made it through the gauntlet. The message survived!
# Processing record 86 of Set 1 | geraldton
# I made it through the gauntlet. The message survived!
# Processing record 87 of Set 1 | georgetown
# I made it through the gauntlet. The message survived!
# Processing record 88 of Set 1 | chegdomyn
# I made it through the gauntlet. The message survived!
# Processing record 89 of Set 1 | cabo san lucas
# I made it through the gauntlet. The message survived!
# Processing record 90 of Set 1 | ambulu
# I made it through the gauntlet. The message survived!
# Processing record 91 of Set 1 | baker city
# I made it through the gauntlet. The message survived!
# Processing record 92 of Set 1 | okha
# I made it through the gauntlet. The message survived!
# Processing record 93 of Set 1 | busselton
# I made it through the gauntlet. The message survived!
# Processing record 94 of Set 1 | atuona
# I made it through the gauntlet. The message survived!
# Processing record 95 of Set 1 | atherton
# I made it through the gauntlet. The message survived!
# Processing record 96 of Set 1 | beringovskiy
# I made it through the gauntlet. The message survived!
# Processing record 97 of Set 1 | novorzhev
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 98 of Set 1 | luderitz
# I made it through the gauntlet. The message survived!
# Processing record 99 of Set 1 | abha
# I made it through the gauntlet. The message survived!
# Processing record 100 of Set 1 | oussouye
# I made it through the gauntlet. The message survived!
# Processing record 101 of Set 1 | ustka
# I made it through the gauntlet. The message survived!
# Processing record 102 of Set 1 | waipawa
# I made it through the gauntlet. The message survived!
# Processing record 103 of Set 1 | aswan
# I made it through the gauntlet. The message survived!
# Processing record 104 of Set 1 | bratsk
# I made it through the gauntlet. The message survived!
# Processing record 105 of Set 1 | rengo
# I made it through the gauntlet. The message survived!
# Processing record 106 of Set 1 | artvin
# I made it through the gauntlet. The message survived!
# Processing record 107 of Set 1 | fayaoue
# I made it through the gauntlet. The message survived!
# Processing record 108 of Set 1 | bowen
# I made it through the gauntlet. The message survived!
# Processing record 109 of Set 1 | coquimbo
# I made it through the gauntlet. The message survived!
# Processing record 110 of Set 1 | kisangani
# I made it through the gauntlet. The message survived!
# Processing record 111 of Set 1 | sola
# I made it through the gauntlet. The message survived!
# Processing record 112 of Set 1 | portland
# I made it through the gauntlet. The message survived!
# Processing record 113 of Set 1 | provideniya
# I made it through the gauntlet. The message survived!
# Processing record 114 of Set 1 | klaksvik
# I made it through the gauntlet. The message survived!
# Processing record 115 of Set 1 | thohoyandou
# I made it through the gauntlet. The message survived!
# Processing record 116 of Set 1 | miquelon
# I made it through the gauntlet. The message survived!
# Processing record 117 of Set 1 | bredasdorp
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 118 of Set 1 | salym
# I made it through the gauntlet. The message survived!
# Processing record 119 of Set 1 | rorvik
# I made it through the gauntlet. The message survived!
# Processing record 120 of Set 1 | vardo
# I made it through the gauntlet. The message survived!
# Processing record 121 of Set 1 | paamiut
# I made it through the gauntlet. The message survived!
# Processing record 122 of Set 1 | srednekolymsk
# I made it through the gauntlet. The message survived!
# Processing record 123 of Set 1 | baturaja
# I made it through the gauntlet. The message survived!
# Processing record 124 of Set 1 | orlik
# I made it through the gauntlet. The message survived!
# Processing record 125 of Set 1 | tupik
# I made it through the gauntlet. The message survived!
# Processing record 126 of Set 1 | vaini
# I made it through the gauntlet. The message survived!
# Processing record 127 of Set 1 | guantanamo
# I made it through the gauntlet. The message survived!
# Processing record 128 of Set 1 | seoul
# I made it through the gauntlet. The message survived!
# Processing record 129 of Set 1 | sao joao da barra
# I made it through the gauntlet. The message survived!
# Processing record 130 of Set 1 | sao filipe
# I made it through the gauntlet. The message survived!
# Processing record 131 of Set 1 | antofagasta
# I made it through the gauntlet. The message survived!
# Processing record 132 of Set 1 | belaya gora
# I made it through the gauntlet. The message survived!
# Processing record 133 of Set 1 | tilichiki
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 134 of Set 1 | ko samui
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 135 of Set 1 | saint-philippe
# I made it through the gauntlet. The message survived!
# Processing record 136 of Set 1 | yellowknife
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 137 of Set 1 | matara
# I made it through the gauntlet. The message survived!
# Processing record 138 of Set 1 | tateyama
# I made it through the gauntlet. The message survived!
# Processing record 139 of Set 1 | ormara
# I made it through the gauntlet. The message survived!
# Processing record 140 of Set 1 | los llanos de aridane
# I made it through the gauntlet. The message survived!
# Processing record 141 of Set 1 | fayetteville
# I made it through the gauntlet. The message survived!
# Processing record 142 of Set 1 | airai
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 143 of Set 1 | tiksi
# I made it through the gauntlet. The message survived!
# Processing record 144 of Set 1 | codrington
# I made it through the gauntlet. The message survived!
# Processing record 145 of Set 1 | gizo
# I made it through the gauntlet. The message survived!
# Processing record 146 of Set 1 | wexford
# I made it through the gauntlet. The message survived!
# Processing record 147 of Set 1 | vila franca do campo
# I made it through the gauntlet. The message survived!
# Processing record 148 of Set 1 | faanui
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 149 of Set 1 | hilo
# I made it through the gauntlet. The message survived!
# Processing record 150 of Set 1 | kieta
# I made it through the gauntlet. The message survived!
# Processing record 151 of Set 1 | chuy
# I made it through the gauntlet. The message survived!
# Processing record 152 of Set 1 | hambantota
# I made it through the gauntlet. The message survived!
# Processing record 153 of Set 1 | keti bandar
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 154 of Set 1 | pangai
# I made it through the gauntlet. The message survived!
# Processing record 155 of Set 1 | vlore
# I made it through the gauntlet. The message survived!
# Processing record 156 of Set 1 | flin flon
# I made it through the gauntlet. The message survived!
# Processing record 157 of Set 1 | uri
# I made it through the gauntlet. The message survived!
# Processing record 158 of Set 1 | wajima
# I made it through the gauntlet. The message survived!
# Processing record 159 of Set 1 | walvis bay
# I made it through the gauntlet. The message survived!
# Processing record 160 of Set 1 | lingao
# I made it through the gauntlet. The message survived!
# Processing record 161 of Set 1 | carauari
# I made it through the gauntlet. The message survived!
# Processing record 162 of Set 1 | novoagansk
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 163 of Set 1 | hasaki
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 164 of Set 1 | joacaba
# I made it through the gauntlet. The message survived!
# Processing record 165 of Set 1 | avera
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 166 of Set 1 | lithakia
# I made it through the gauntlet. The message survived!
# Processing record 167 of Set 1 | yulara
# I made it through the gauntlet. The message survived!
# Processing record 168 of Set 1 | namibe
# I made it through the gauntlet. The message survived!
# Processing record 169 of Set 1 | bembibre
# I made it through the gauntlet. The message survived!
# Processing record 170 of Set 1 | palmer
# I made it through the gauntlet. The message survived!
# Processing record 171 of Set 1 | coihaique
# I made it through the gauntlet. The message survived!
# Processing record 172 of Set 1 | bunia
# I made it through the gauntlet. The message survived!
# Processing record 173 of Set 1 | salalah
# I made it through the gauntlet. The message survived!
# Processing record 174 of Set 1 | kungurtug
# I made it through the gauntlet. The message survived!
# Processing record 175 of Set 1 | yumen
# I made it through the gauntlet. The message survived!
# Processing record 176 of Set 1 | tromso
# I made it through the gauntlet. The message survived!
# Processing record 177 of Set 1 | namatanai
# I made it through the gauntlet. The message survived!
# Processing record 178 of Set 1 | cidreira
# I made it through the gauntlet. The message survived!
# Processing record 179 of Set 1 | nioro
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 180 of Set 1 | senanga
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 181 of Set 1 | karasjok
# I made it through the gauntlet. The message survived!
# Processing record 182 of Set 1 | cedar lake
# I made it through the gauntlet. The message survived!
# Processing record 183 of Set 1 | kokomo
# I made it through the gauntlet. The message survived!
# Processing record 184 of Set 1 | dodge city
# I made it through the gauntlet. The message survived!
# Processing record 185 of Set 1 | bathsheba
# I made it through the gauntlet. The message survived!
# Processing record 186 of Set 1 | ribeira grande
# I made it through the gauntlet. The message survived!
# Processing record 187 of Set 1 | longyearbyen
# I made it through the gauntlet. The message survived!
# Processing record 188 of Set 1 | ponta do sol
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 189 of Set 1 | hobart
# I made it through the gauntlet. The message survived!
# Processing record 190 of Set 1 | barrow
# I made it through the gauntlet. The message survived!
# Processing record 191 of Set 1 | denizli
# I made it through the gauntlet. The message survived!
# Processing record 192 of Set 1 | rimbey
# I made it through the gauntlet. The message survived!
# Processing record 193 of Set 1 | teya
# I made it through the gauntlet. The message survived!
# Processing record 194 of Set 1 | saint-augustin
# I made it through the gauntlet. The message survived!
# Processing record 195 of Set 1 | ati
# I made it through the gauntlet. The message survived!
# Processing record 196 of Set 1 | krasne
# I made it through the gauntlet. The message survived!
# Processing record 197 of Set 1 | long beach
# I made it through the gauntlet. The message survived!
# Processing record 198 of Set 1 | tokur
# I made it through the gauntlet. The message survived!
# Processing record 199 of Set 1 | san patricio
# I made it through the gauntlet. The message survived!
# Processing record 200 of Set 1 | owosso
# I made it through the gauntlet. The message survived!
# Processing record 201 of Set 1 | la ronge
# I made it through the gauntlet. The message survived!
# Processing record 202 of Set 1 | lishan
# I made it through the gauntlet. The message survived!
# Processing record 203 of Set 1 | carhuamayo
# I made it through the gauntlet. The message survived!
# Processing record 204 of Set 1 | balkanabat
# I made it through the gauntlet. The message survived!
# Processing record 205 of Set 1 | norman wells
# I made it through the gauntlet. The message survived!
# Processing record 206 of Set 1 | cumra
# I made it through the gauntlet. The message survived!
# Processing record 207 of Set 1 | gushikawa
# I made it through the gauntlet. The message survived!
# Processing record 208 of Set 1 | kirkland lake
# I made it through the gauntlet. The message survived!
# Processing record 209 of Set 1 | nouakchott
# I made it through the gauntlet. The message survived!
# Processing record 210 of Set 1 | saint-francois
# I made it through the gauntlet. The message survived!
# Processing record 211 of Set 1 | buckeye
# I made it through the gauntlet. The message survived!
# Processing record 212 of Set 1 | coahuayana
# I made it through the gauntlet. The message survived!
# Processing record 213 of Set 1 | pevek
# I made it through the gauntlet. The message survived!
# Processing record 214 of Set 1 | dikson
# I made it through the gauntlet. The message survived!
# Processing record 215 of Set 1 | turukhansk
# I made it through the gauntlet. The message survived!
# Processing record 216 of Set 1 | sturgeon falls
# I made it through the gauntlet. The message survived!
# Processing record 217 of Set 1 | leningradskiy
# I made it through the gauntlet. The message survived!
# Processing record 218 of Set 1 | qasigiannguit
# I made it through the gauntlet. The message survived!
# Processing record 219 of Set 1 | ulladulla
# I made it through the gauntlet. The message survived!
# Processing record 220 of Set 1 | bend
# I made it through the gauntlet. The message survived!
# Processing record 221 of Set 1 | banswara
# I made it through the gauntlet. The message survived!
# Processing record 222 of Set 1 | huallanca
# I made it through the gauntlet. The message survived!
# Processing record 223 of Set 1 | mayumba
# I made it through the gauntlet. The message survived!
# Processing record 224 of Set 1 | port arthur
# I made it through the gauntlet. The message survived!
# Processing record 225 of Set 1 | maputo
# I made it through the gauntlet. The message survived!
# Processing record 226 of Set 1 | chokurdakh
# I made it through the gauntlet. The message survived!
# Processing record 227 of Set 1 | port hardy
# I made it through the gauntlet. The message survived!
# Processing record 228 of Set 1 | lebu
# I made it through the gauntlet. The message survived!
# Processing record 229 of Set 1 | kasane
# I made it through the gauntlet. The message survived!
# Processing record 230 of Set 1 | samarai
# I made it through the gauntlet. The message survived!
# Processing record 231 of Set 1 | williston
# I made it through the gauntlet. The message survived!
# Processing record 232 of Set 1 | tacuarembo
# I made it through the gauntlet. The message survived!
# Processing record 233 of Set 1 | sitka
# I made it through the gauntlet. The message survived!
# Processing record 234 of Set 1 | lumberton
# I made it through the gauntlet. The message survived!
# Processing record 235 of Set 1 | anadyr
# I made it through the gauntlet. The message survived!
# Processing record 236 of Set 1 | tirano
# I made it through the gauntlet. The message survived!
# Processing record 237 of Set 1 | cristalina
# I made it through the gauntlet. The message survived!
# Processing record 238 of Set 1 | paveh
# I made it through the gauntlet. The message survived!
# Processing record 239 of Set 1 | norden
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 240 of Set 1 | ostroleka
# I made it through the gauntlet. The message survived!
# Processing record 241 of Set 1 | isangel
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 242 of Set 1 | alofi
# I made it through the gauntlet. The message survived!
# Processing record 243 of Set 1 | san cristobal
# I made it through the gauntlet. The message survived!
# Processing record 244 of Set 1 | nabire
# I made it through the gauntlet. The message survived!
# Processing record 245 of Set 1 | maniwaki
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 246 of Set 1 | champerico
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 247 of Set 1 | ilulissat
# I made it through the gauntlet. The message survived!
# Processing record 248 of Set 1 | vaitape
# I made it through the gauntlet. The message survived!
# Processing record 249 of Set 1 | quang ngai
# I made it through the gauntlet. The message survived!
# Processing record 250 of Set 1 | kjopsvik
# I made it through the gauntlet. The message survived!
# Processing record 251 of Set 1 | lompoc
# I made it through the gauntlet. The message survived!
# Processing record 252 of Set 1 | mokhsogollokh
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 253 of Set 1 | baoqing
# I made it through the gauntlet. The message survived!
# Processing record 254 of Set 1 | wattegama
# I made it through the gauntlet. The message survived!
# Processing record 255 of Set 1 | luocheng
# I made it through the gauntlet. The message survived!
# Processing record 256 of Set 1 | vestmannaeyjar
# I made it through the gauntlet. The message survived!
# Processing record 257 of Set 1 | san francisco menendez
# I made it through the gauntlet. The message survived!
# Processing record 258 of Set 1 | kavaratti
# I made it through the gauntlet. The message survived!
# Processing record 259 of Set 1 | nikolayevsk-na-amure
# I made it through the gauntlet. The message survived!
# Processing record 260 of Set 1 | mezen
# I made it through the gauntlet. The message survived!
# Processing record 261 of Set 1 | apahida
# I made it through the gauntlet. The message survived!
# Processing record 262 of Set 1 | borogontsy
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 263 of Set 1 | shitanjing
# I made it through the gauntlet. The message survived!
# Processing record 264 of Set 1 | brae
# I made it through the gauntlet. The message survived!
# Processing record 265 of Set 1 | manoel urbano
# I made it through the gauntlet. The message survived!
# Processing record 266 of Set 1 | fukue
# I made it through the gauntlet. The message survived!
# Processing record 267 of Set 1 | te anau
# I made it through the gauntlet. The message survived!
# Processing record 268 of Set 1 | birao
# I made it through the gauntlet. The message survived!
# Processing record 269 of Set 1 | padang
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 270 of Set 1 | torbay
# I made it through the gauntlet. The message survived!
# Processing record 271 of Set 1 | miyako
# I made it through the gauntlet. The message survived!
# Processing record 272 of Set 1 | hastings
# I made it through the gauntlet. The message survived!
# Processing record 273 of Set 1 | mocuba
# I made it through the gauntlet. The message survived!
# Processing record 274 of Set 1 | manyana
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 275 of Set 1 | shangzhi
# I made it through the gauntlet. The message survived!
# Processing record 276 of Set 1 | baiyin
# I made it through the gauntlet. The message survived!
# Processing record 277 of Set 1 | roma
# I made it through the gauntlet. The message survived!
# Processing record 278 of Set 1 | kayerkan
# I made it through the gauntlet. The message survived!
# Processing record 279 of Set 1 | narsaq
# I made it through the gauntlet. The message survived!
# Processing record 280 of Set 1 | traverse city
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 281 of Set 1 | krasnopavlivka
# I made it through the gauntlet. The message survived!
# Processing record 282 of Set 1 | basoko
# I made it through the gauntlet. The message survived!
# Processing record 283 of Set 1 | hofn
# I made it through the gauntlet. The message survived!
# Processing record 284 of Set 1 | sobolevo
# I made it through the gauntlet. The message survived!
# Processing record 285 of Set 1 | bethel
# I made it through the gauntlet. The message survived!
# Processing record 286 of Set 1 | presidente olegario
# I made it through the gauntlet. The message survived!
# Processing record 287 of Set 1 | sao jose da tapera
# I made it through the gauntlet. The message survived!
# Processing record 288 of Set 1 | mabaruma
# I made it through the gauntlet. The message survived!
# Processing record 289 of Set 1 | redlands
# I made it through the gauntlet. The message survived!
# Processing record 290 of Set 1 | ugoofaaru
# I made it through the gauntlet. The message survived!
# Processing record 291 of Set 1 | iquique
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 292 of Set 1 | garowe
# I made it through the gauntlet. The message survived!
# Processing record 293 of Set 1 | marawi
# I made it through the gauntlet. The message survived!
# Processing record 294 of Set 1 | morgan city
# I made it through the gauntlet. The message survived!
# Processing record 295 of Set 1 | shunyi
# I made it through the gauntlet. The message survived!
# Processing record 296 of Set 1 | rawson
# I made it through the gauntlet. The message survived!
# Processing record 297 of Set 1 | lavrentiya
# I made it through the gauntlet. The message survived!
# Processing record 298 of Set 1 | sao gabriel da cachoeira
# I made it through the gauntlet. The message survived!
# Processing record 299 of Set 1 | tadine
# I made it through the gauntlet. The message survived!
# Processing record 300 of Set 1 | sinop
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 301 of Set 1 | oliveira dos brejinhos
# I made it through the gauntlet. The message survived!
# Processing record 302 of Set 1 | prince rupert
# I made it through the gauntlet. The message survived!
# Processing record 303 of Set 1 | ngunguru
# I made it through the gauntlet. The message survived!
# Processing record 304 of Set 1 | victoria
# I made it through the gauntlet. The message survived!
# Processing record 305 of Set 1 | sebinkarahisar
# I made it through the gauntlet. The message survived!
# Processing record 306 of Set 1 | mamallapuram
# I made it through the gauntlet. The message survived!
# Processing record 307 of Set 1 | tessalit
# I made it through the gauntlet. The message survived!
# Processing record 308 of Set 1 | clyde river
# I made it through the gauntlet. The message survived!
# Processing record 309 of Set 1 | vila velha
# I made it through the gauntlet. The message survived!
# Processing record 310 of Set 1 | sisimiut
# I made it through the gauntlet. The message survived!
# Processing record 311 of Set 1 | fortuna
# I made it through the gauntlet. The message survived!
# Processing record 312 of Set 1 | bambous virieux
# I made it through the gauntlet. The message survived!
# Processing record 313 of Set 1 | isla mujeres
# I made it through the gauntlet. The message survived!
# Processing record 314 of Set 1 | peniche
# I made it through the gauntlet. The message survived!
# Processing record 315 of Set 1 | savinka
# I made it through the gauntlet. The message survived!
# Processing record 316 of Set 1 | fairlie
# I made it through the gauntlet. The message survived!
# Processing record 317 of Set 1 | dwarka
# I made it through the gauntlet. The message survived!
# Processing record 318 of Set 1 | boyolangu
# I made it through the gauntlet. The message survived!
# Processing record 319 of Set 1 | jakar
# I made it through the gauntlet. The message survived!
# Processing record 320 of Set 1 | pedernales
# I made it through the gauntlet. The message survived!
# Processing record 321 of Set 1 | arlit
# I made it through the gauntlet. The message survived!
# Processing record 322 of Set 1 | fairbanks
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 323 of Set 1 | oppdal
# I made it through the gauntlet. The message survived!
# Processing record 324 of Set 1 | okhotsk
# I made it through the gauntlet. The message survived!
# Processing record 325 of Set 1 | sinnamary
# I made it through the gauntlet. The message survived!
# Processing record 326 of Set 1 | panacan
# I made it through the gauntlet. The message survived!
# Processing record 327 of Set 1 | abu samrah
# I made it through the gauntlet. The message survived!
# Processing record 328 of Set 1 | turbat
# I made it through the gauntlet. The message survived!
# Processing record 329 of Set 1 | kaitangata
# I made it through the gauntlet. The message survived!
# Processing record 330 of Set 1 | riyadh
# I made it through the gauntlet. The message survived!
# Processing record 331 of Set 1 | hayden
# I made it through the gauntlet. The message survived!
# Processing record 332 of Set 1 | caruray
# I made it through the gauntlet. The message survived!
# Processing record 333 of Set 1 | road town
# I made it through the gauntlet. The message survived!
# Processing record 334 of Set 1 | la seyne-sur-mer
# I made it through the gauntlet. The message survived!
# Processing record 335 of Set 1 | shima
# I made it through the gauntlet. The message survived!
# Processing record 336 of Set 1 | jiaozuo
# I made it through the gauntlet. The message survived!
# Processing record 337 of Set 1 | nuuk
# I made it through the gauntlet. The message survived!
# Processing record 338 of Set 1 | tazovskiy
# I made it through the gauntlet. The message survived!
# Processing record 339 of Set 1 | pangoa
# I made it through the gauntlet. The message survived!
# Processing record 340 of Set 1 | aklavik
# I made it through the gauntlet. The message survived!
# Processing record 341 of Set 1 | inhambane
# I made it through the gauntlet. The message survived!
# Processing record 342 of Set 1 | sibolga
# I made it through the gauntlet. The message survived!
# Processing record 343 of Set 1 | jalu
# I made it through the gauntlet. The message survived!
# Processing record 344 of Set 1 | malinyi
# I made it through the gauntlet. The message survived!
# Processing record 345 of Set 1 | tucuman
# I made it through the gauntlet. The message survived!
# Processing record 346 of Set 1 | istiaia
# I made it through the gauntlet. The message survived!
# Processing record 347 of Set 1 | san quintin
# I made it through the gauntlet. The message survived!
# Processing record 348 of Set 1 | aquin
# I made it through the gauntlet. The message survived!
# Processing record 349 of Set 1 | diamantino
# I made it through the gauntlet. The message survived!
# Processing record 350 of Set 1 | rancho palos verdes
# I made it through the gauntlet. The message survived!
# Processing record 351 of Set 1 | waingapu
# I made it through the gauntlet. The message survived!
# Processing record 352 of Set 1 | mayor pablo lagerenza
# I made it through the gauntlet. The message survived!
# Processing record 353 of Set 1 | milkovo
# I made it through the gauntlet. The message survived!
# Processing record 354 of Set 1 | dunedin
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 355 of Set 1 | imbituba
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 356 of Set 1 | chapleau
# I made it through the gauntlet. The message survived!
# Processing record 357 of Set 1 | tete
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 358 of Set 1 | abu dhabi
# I made it through the gauntlet. The message survived!
# Processing record 359 of Set 1 | bubaque
# I made it through the gauntlet. The message survived!
# Processing record 360 of Set 1 | mogadishu
# I made it through the gauntlet. The message survived!
# Processing record 361 of Set 1 | luziania
# I made it through the gauntlet. The message survived!
# Processing record 362 of Set 1 | kilindoni
# I made it through the gauntlet. The message survived!
# Processing record 363 of Set 1 | kuytun
# I made it through the gauntlet. The message survived!
# Processing record 364 of Set 1 | jinchang
# I made it through the gauntlet. The message survived!
# Processing record 365 of Set 1 | lodja
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 366 of Set 1 | tiarei
# I made it through the gauntlet. The message survived!
# Processing record 367 of Set 1 | maceio
# I made it through the gauntlet. The message survived!
# Processing record 368 of Set 1 | zharkent
# I made it through the gauntlet. The message survived!
# Processing record 369 of Set 1 | ostrovnoy
# I made it through the gauntlet. The message survived!
# Processing record 370 of Set 1 | santona
# I made it through the gauntlet. The message survived!
# Processing record 371 of Set 1 | iralaya
# I made it through the gauntlet. The message survived!
# Processing record 372 of Set 1 | camara de lobos
# I made it through the gauntlet. The message survived!
# Processing record 373 of Set 1 | briancon
# I made it through the gauntlet. The message survived!
# Processing record 374 of Set 1 | sandeid
# I made it through the gauntlet. The message survived!
# Processing record 375 of Set 1 | pechora
# I made it through the gauntlet. The message survived!
# Processing record 376 of Set 1 | bayan
# I made it through the gauntlet. The message survived!
# Processing record 377 of Set 1 | kalmunai
# I made it through the gauntlet. The message survived!
# Processing record 378 of Set 1 | atambua
# I made it through the gauntlet. The message survived!
# Processing record 379 of Set 1 | tura
# I made it through the gauntlet. The message survived!
# Processing record 380 of Set 1 | bud
# I made it through the gauntlet. The message survived!
# Processing record 381 of Set 1 | porto belo
# I made it through the gauntlet. The message survived!
# Processing record 382 of Set 1 | emerald
# I made it through the gauntlet. The message survived!
# Processing record 383 of Set 1 | vostok
# I made it through the gauntlet. The message survived!
# Processing record 384 of Set 1 | lasa
# I made it through the gauntlet. The message survived!
# Processing record 385 of Set 1 | mercedes
# I made it through the gauntlet. The message survived!
# Processing record 386 of Set 1 | robertsport
# I made it through the gauntlet. The message survived!
# Processing record 387 of Set 1 | price
# I made it through the gauntlet. The message survived!
# Processing record 388 of Set 1 | trinidad
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 389 of Set 1 | maraa
# I made it through the gauntlet. The message survived!
# Processing record 390 of Set 1 | mar del plata
# I made it through the gauntlet. The message survived!
# Processing record 391 of Set 1 | platteville
# I made it through the gauntlet. The message survived!
# Processing record 392 of Set 1 | cockburn town
# I made it through the gauntlet. The message survived!
# Processing record 393 of Set 1 | guerrero negro
# I made it through the gauntlet. The message survived!
# Processing record 394 of Set 1 | lukovetskiy
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 395 of Set 1 | harper
# I made it through the gauntlet. The message survived!
# Processing record 396 of Set 1 | nakuru
# I made it through the gauntlet. The message survived!
# Processing record 397 of Set 1 | bacolod
# I made it through the gauntlet. The message survived!
# Processing record 398 of Set 1 | havoysund
# I made it through the gauntlet. The message survived!
# Processing record 399 of Set 1 | am timan
# I made it through the gauntlet. The message survived!
# Processing record 400 of Set 1 | naze
# I made it through the gauntlet. The message survived!
# Processing record 401 of Set 1 | aksha
# I made it through the gauntlet. The message survived!
# Processing record 402 of Set 1 | port hedland
# I made it through the gauntlet. The message survived!
# Processing record 403 of Set 1 | kastamonu
# I made it through the gauntlet. The message survived!
# Processing record 404 of Set 1 | monrovia
# I made it through the gauntlet. The message survived!
# Processing record 405 of Set 1 | honningsvag
# I made it through the gauntlet. The message survived!
# Processing record 406 of Set 1 | pangnirtung
# I made it through the gauntlet. The message survived!
# Processing record 407 of Set 1 | biltine
# I made it through the gauntlet. The message survived!
# Processing record 408 of Set 1 | ambanja
# I made it through the gauntlet. The message survived!
# Processing record 409 of Set 1 | petatlan
# I made it through the gauntlet. The message survived!
# Processing record 410 of Set 1 | san policarpo
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 411 of Set 1 | eskisehir
# I made it through the gauntlet. The message survived!
# Processing record 412 of Set 1 | mpongwe
# I made it through the gauntlet. The message survived!
# Processing record 413 of Set 1 | port blair
# I made it through the gauntlet. The message survived!
# Processing record 414 of Set 1 | dalbandin
# I made it through the gauntlet. The message survived!
# Processing record 415 of Set 1 | gazojak
# I made it through the gauntlet. The message survived!
# Processing record 416 of Set 1 | moerai
# I made it through the gauntlet. The message survived!
# Processing record 417 of Set 1 | masumbwe
# I made it through the gauntlet. The message survived!
# Processing record 418 of Set 1 | codo
# I made it through the gauntlet. The message survived!
# Processing record 419 of Set 1 | nankana sahib
# I made it through the gauntlet. The message survived!
# Processing record 420 of Set 1 | parry sound
# I made it through the gauntlet. The message survived!
# Processing record 421 of Set 1 | ariquemes
# I made it through the gauntlet. The message survived!
# Processing record 422 of Set 1 | nanortalik
# I made it through the gauntlet. The message survived!
# Processing record 423 of Set 1 | kolosovka
# I made it through the gauntlet. The message survived!
# Processing record 424 of Set 1 | thessalon
# I made it through the gauntlet. The message survived!
# Processing record 425 of Set 1 | diffa
# I made it through the gauntlet. The message survived!
# Processing record 426 of Set 1 | zeya
# I made it through the gauntlet. The message survived!
# Processing record 427 of Set 1 | teeli
# I made it through the gauntlet. The message survived!
# Processing record 428 of Set 1 | talnakh
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 429 of Set 1 | salvador
# I made it through the gauntlet. The message survived!
# Processing record 430 of Set 1 | kruisfontein
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 431 of Set 1 | huancabamba
# I made it through the gauntlet. The message survived!
# Processing record 432 of Set 1 | san juan
# I made it through the gauntlet. The message survived!
# Processing record 433 of Set 1 | nha trang
# I made it through the gauntlet. The message survived!
# Processing record 434 of Set 1 | belmonte
# I made it through the gauntlet. The message survived!
# Processing record 435 of Set 1 | apollonia
# I made it through the gauntlet. The message survived!
# Processing record 436 of Set 1 | leshukonskoye
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 437 of Set 1 | ranong
# I made it through the gauntlet. The message survived!
# Processing record 438 of Set 1 | bolivar
# I made it through the gauntlet. The message survived!
# Processing record 439 of Set 1 | brigantine
# I made it through the gauntlet. The message survived!
# Processing record 440 of Set 1 | hornepayne
# I made it through the gauntlet. The message survived!
# Processing record 441 of Set 1 | bollene
# I made it through the gauntlet. The message survived!
# Processing record 442 of Set 1 | stokmarknes
# I made it through the gauntlet. The message survived!
# Processing record 443 of Set 1 | kendari
# I made it through the gauntlet. The message survived!
# Processing record 444 of Set 1 | codajas
# I made it through the gauntlet. The message survived!
# Processing record 445 of Set 1 | khatanga
# I made it through the gauntlet. The message survived!
# Processing record 446 of Set 1 | richards bay
# I made it through the gauntlet. The message survived!
# Processing record 447 of Set 1 | kytmanovo
# I made it through the gauntlet. The message survived!
# Processing record 448 of Set 1 | salihli
# I made it through the gauntlet. The message survived!
# Processing record 449 of Set 1 | aguas formosas
# I made it through the gauntlet. The message survived!
# Processing record 450 of Set 1 | shelburne
# I made it through the gauntlet. The message survived!
# Processing record 451 of Set 1 | dzhebariki-khaya
# I made it through the gauntlet. The message survived!
# Processing record 452 of Set 1 | chicama
# I made it through the gauntlet. The message survived!
# Processing record 453 of Set 1 | genhe
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 454 of Set 1 | kapit
# I made it through the gauntlet. The message survived!
# Processing record 455 of Set 1 | conde
# I made it through the gauntlet. The message survived!
# Processing record 456 of Set 1 | divnomorskoye
# I made it through the gauntlet. The message survived!
# Processing record 457 of Set 1 | yarkovo
# I made it through the gauntlet. The message survived!
# Processing record 458 of Set 1 | kushima
# I made it through the gauntlet. The message survived!
# Processing record 459 of Set 1 | xianshuigu
# I made it through the gauntlet. The message survived!
# Processing record 460 of Set 1 | puerto escondido
# I made it through the gauntlet. The message survived!
# Processing record 461 of Set 1 | tallahassee
# I made it through the gauntlet. The message survived!
# Processing record 462 of Set 1 | kirakira
# I made it through the gauntlet. The message survived!
# Processing record 463 of Set 1 | fare
# I made it through the gauntlet. The message survived!
# Processing record 464 of Set 1 | pitelino
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 465 of Set 1 | dudinka
# I made it through the gauntlet. The message survived!
# Processing record 466 of Set 1 | gwanda
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 467 of Set 1 | melegnano
# I made it through the gauntlet. The message survived!
# Processing record 468 of Set 1 | saint anthony
# I made it through the gauntlet. The message survived!
# Processing record 469 of Set 1 | mizdah
# I made it through the gauntlet. The message survived!
# Processing record 470 of Set 1 | shenjiamen
# I made it through the gauntlet. The message survived!
# Processing record 471 of Set 1 | yerbogachen
# I made it through the gauntlet. The message survived!
# Processing record 472 of Set 1 | erenhot
# I made it through the gauntlet. The message survived!
# Processing record 473 of Set 1 | pabrade
# I made it through the gauntlet. The message survived!
# Processing record 474 of Set 1 | disraeli
# I made it through the gauntlet. The message survived!
# Processing record 475 of Set 1 | tual
# I made it through the gauntlet. The message survived!
# Processing record 476 of Set 1 | leh
# I made it through the gauntlet. The message survived!
# Processing record 477 of Set 1 | harnosand
# I made it through the gauntlet. The message survived!
# Processing record 478 of Set 1 | pirovskoye
# I made it through the gauntlet. The message survived!
# Processing record 479 of Set 1 | camabatela
# I made it through the gauntlet. The message survived!
# Processing record 480 of Set 1 | necochea
# I made it through the gauntlet. The message survived!
# Processing record 481 of Set 1 | sorland
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 482 of Set 1 | katangli
# I made it through the gauntlet. The message survived!
# Processing record 483 of Set 1 | sirsi
# I made it through the gauntlet. The message survived!
# Processing record 484 of Set 1 | vao
# I made it through the gauntlet. The message survived!
# Processing record 485 of Set 1 | nieuw nickerie
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 486 of Set 1 | weihe
# I made it through the gauntlet. The message survived!
# Processing record 487 of Set 1 | umea
# I made it through the gauntlet. The message survived!
# Processing record 488 of Set 1 | burnie
# I made it through the gauntlet. The message survived!
# Processing record 489 of Set 1 | conceicao da barra
# I made it through the gauntlet. The message survived!
# Processing record 490 of Set 1 | virtsu
# I made it through the gauntlet. The message survived!
# Processing record 491 of Set 1 | sinor
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 492 of Set 1 | linhares
# I made it through the gauntlet. The message survived!
# Processing record 493 of Set 1 | villiers
# I made it through the gauntlet. The message survived!
# Processing record 494 of Set 1 | houma
# I made it through the gauntlet. The message survived!
# Processing record 495 of Set 1 | ahipara
# I made it through the gauntlet. The message survived!
# Processing record 496 of Set 1 | gornopravdinsk
# I made it through the gauntlet. The message survived!
# Processing record 497 of Set 1 | udachnyy
# I made it through the gauntlet. The message survived!
# Processing record 498 of Set 1 | aykhal
# I made it through the gauntlet. The message survived!
# Processing record 499 of Set 1 | kyabe
# I made it through the gauntlet. The message survived!
# Processing record 500 of Set 1 | upata
# I made it through the gauntlet. The message survived!
# Processing record 501 of Set 1 | birin
# I made it through the gauntlet. The message survived!
# Processing record 502 of Set 1 | qandala
# I made it through the gauntlet. The message survived!
# Processing record 503 of Set 1 | yeppoon
# I made it through the gauntlet. The message survived!
# Processing record 504 of Set 1 | sistranda
# I made it through the gauntlet. The message survived!
# Processing record 505 of Set 1 | bandarbeyla
# I made it through the gauntlet. The message survived!
# Processing record 506 of Set 1 | kerema
# I made it through the gauntlet. The message survived!
# Processing record 507 of Set 1 | bhatkal
# I made it through the gauntlet. The message survived!
# Processing record 508 of Set 1 | caravelas
# I made it through the gauntlet. The message survived!
# Processing record 509 of Set 1 | goderich
# I made it through the gauntlet. The message survived!
# Processing record 510 of Set 1 | mantua
# I made it through the gauntlet. The message survived!
# Processing record 511 of Set 1 | huarmey
# I made it through the gauntlet. The message survived!
# Processing record 512 of Set 1 | lubao
# I made it through the gauntlet. The message survived!
# Processing record 513 of Set 1 | bulawayo
# I made it through the gauntlet. The message survived!
# Processing record 514 of Set 1 | mareeba
# I made it through the gauntlet. The message survived!
# Processing record 515 of Set 1 | ambilobe
# I made it through the gauntlet. The message survived!
# Processing record 516 of Set 1 | skibbereen
# I made it through the gauntlet. The message survived!
# Processing record 517 of Set 1 | gazli
# I made it through the gauntlet. The message survived!
# Processing record 518 of Set 1 | havre
# I made it through the gauntlet. The message survived!
# Processing record 519 of Set 1 | los teques
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 520 of Set 1 | kavieng
# I made it through the gauntlet. The message survived!
# Processing record 521 of Set 1 | las cruces
# I made it through the gauntlet. The message survived!
# Processing record 522 of Set 1 | husavik
# I made it through the gauntlet. The message survived!
# Processing record 523 of Set 1 | pastavy
# I made it through the gauntlet. The message survived!
# Processing record 524 of Set 1 | balarampur
# I made it through the gauntlet. The message survived!
# Processing record 525 of Set 1 | aqtobe
# I made it through the gauntlet. The message survived!
# Processing record 526 of Set 1 | dingle
# I made it through the gauntlet. The message survived!
# Processing record 527 of Set 1 | half moon bay
# I made it through the gauntlet. The message survived!
# Processing record 528 of Set 1 | uvat
# I made it through the gauntlet. The message survived!
# Processing record 529 of Set 1 | linxia
# I made it through the gauntlet. The message survived!
# Processing record 530 of Set 1 | pointe michel
# I made it through the gauntlet. The message survived!
# Processing record 531 of Set 1 | ternate
# I made it through the gauntlet. The message survived!
# Processing record 532 of Set 1 | norfolk
# I made it through the gauntlet. The message survived!
# Processing record 533 of Set 1 | atar
# I made it through the gauntlet. The message survived!
# Processing record 534 of Set 1 | thanh hoa
# I made it through the gauntlet. The message survived!
# Processing record 535 of Set 1 | saint-pierre
# I made it through the gauntlet. The message survived!
# Processing record 536 of Set 1 | fort nelson
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Record not found
# I made it through the gauntlet. The message survived!
# Processing record 537 of Set 1 | muros
# I made it through the gauntlet. The message survived!
# Processing record 538 of Set 1 | alice springs
# I made it through the gauntlet. The message survived!
# Processing record 539 of Set 1 | worthington
# I made it through the gauntlet. The message survived!
# Processing record 540 of Set 1 | oranjemund
# I made it through the gauntlet. The message survived!
# Processing record 541 of Set 1 | narasapur
# I made it through the gauntlet. The message survived!
# Processing record 542 of Set 1 | morondava
# I made it through the gauntlet. The message survived!
# Processing record 543 of Set 1 | taldan
# I made it through the gauntlet. The message survived!

# %%
# Convert array of JSONs into Pandas DataFrame
weather_dict = {"City": city_name, "Latitude": lat, "Longitude":lng,
                "Max Temp":max_temp, "Humidity":humidity, "Cloudiness":cloudiness,
                "Wind Speed":wind_speed, "Country":country, "Date":date}
weather_data = pd.DataFrame(weather_dict)

# %%
# Export the City_Data into a csv

weather_data.to_csv(r'output_data\my_weather_data.csv')

# Show Record Count
record_count = len(weather_data)
record_count
# Out:
# 543

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# Show Record Count

# %%
# Display the City Data Frame
weather_data.head()
# Out:
#           City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0     Hermanus  -34.4176    19.2361     63.41        79         100
# 1   Brookhaven   40.7793   -72.9154     59.96        63         100
# 2  Tuktoyaktuk   69.4440  -133.0320     15.91        84           0
# 3         Nome   30.0358   -94.4244     84.96        69           0
# 4    Hithadhoo   -0.6000    73.0833     80.88        79         100
#
#    Wind Speed Country        Date
# 0       11.30      ZA  1571594400
# 1        6.62      US  1571594400
# 2       19.53      CA  1571594400
# 3       12.48      US  1571594400
# 4       11.61      MV  1571594400

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(lat,
           max_temp,
           edgecolor="black",
           linewidths=1,
           marker="o",
           alpha=0.8,
           label="Cities")

# Incorporate the other graph properties
plt.title('City Latitude vs. Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid(True)

# Save the figure
plt.savefig("Lat VS Max_Temp Scatter")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(lat,
           humidity,
           edgecolor="black",
           linewidths=1,
           marker="o",
           alpha=0.8,
           label="Cities")

# Incorporate the other graph properties
plt.title('City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)

# Save the figure
plt.savefig("Lat VS Humidity Scatter")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(lat,
           cloudiness,
           edgecolor="black",
           linewidths=1,
           marker="o",
           alpha=0.8,
           label="Cities")

# Incorporate the other graph properties
plt.title('City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)

# Save the figure
plt.savefig("Lat VS Cloudiness Scatter")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(lat,
           wind_speed,
           edgecolor="black",
           linewidths=1,
           marker="o",
           alpha=0.8,
           label="Cities")

# Incorporate the other graph properties
plt.title('City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(True)

# Save the figure
plt.savefig("Lat VS Wind_Speed Scatter")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
        
# Run regresson on southern hemisphere
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=14,color="red")
    plt.xlabel("Latitude")
    plt.ylabel(title)
    print(f"The r-squared is: {rvalue}")
    
# Plot
plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
north_hem_df = weather_data.loc[weather_data["Latitude"] >= 0,:]
south_hem_df = weather_data.loc[weather_data["Latitude"] < 0,:]

# %% [markdown]
# ###  Max Temp vs. Latitude Linear Regression

# %%
# Linear regression on Northern Hemisphere
x_values = north_hem_df["Latitude"]
y_values = north_hem_df["Max Temp"]
plot_linear_regression(x_values,y_values,'Max Temp',(6,30))

plt.savefig("Max_Temp VS Lat LR")
# Out:
# The r-squared is: -0.8678616439649426

# %%
# Linear regression on Southern Hemisphere
x_values = south_hem_df["Latitude"]
y_values = south_hem_df["Max Temp"]
plot_linear_regression(x_values,y_values,'Max Temp',(6,30))

plt.savefig("S-Max_Temp VS Lat LR")

print("The high r value indicates a strong positive correlation between latitude and max temperature.")
# Out:
# The r-squared is: 0.6310164147234135
# The high r value indicates a strong positive correlation between latitude and max temperature.

# %% [markdown]
# The high r value indicates a strong positive correlation between latitude and max temperature.

# %% [markdown]
# ### Humidity (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere
x_values = north_hem_df["Latitude"]
y_values = north_hem_df["Humidity"]
plot_linear_regression(x_values,y_values,'Humidity',(6,30))

plt.savefig("N-Humidity VS Lat LR")
# Out:
# The r-squared is: 0.1898286898953863

# %%
# Southern Hemisphere
x_values = south_hem_df["Latitude"]
y_values = south_hem_df["Humidity"]
plot_linear_regression(x_values,y_values,'Humidity',(6,30))

plt.savefig("S-Humidity VS Lat LR")

print("The low r values indicate a weak to no relationship between humidity and latitude.")
# Out:
# The r-squared is: 0.008315986811628442
# The low r values indicate a weak to no relationship between humidity and latitude.

# %% [markdown]
# The low r values indicate a weak to no relationship between humidity and latitude.

# %% [markdown]
# ### Cloudiness (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere
x_values = north_hem_df["Latitude"]
y_values = north_hem_df["Cloudiness"]
plot_linear_regression(x_values,y_values,'Cloudiness',(6,30))

plt.savefig("N-Cloud VS Lat LR")
# Out:
# The r-squared is: 0.14721380468015935

# %%
# Southern Hemisphere
x_values = south_hem_df["Latitude"]
y_values = south_hem_df["Cloudiness"]
plot_linear_regression(x_values,y_values,'Cloudiness',(6,30))

plt.savefig("S-Cloud VS Lat LR")

print("The low r values indicate a weak positive relationship between latitude and cloudiness.")
# Out:
# The r-squared is: 0.056557213495224704
# The low r values indicate a weak positive relationship between latitude and cloudiness.

# %% [markdown]
# The low r values indicate a weak positive relationship between latitude and cloudiness.

# %% [markdown]
# ### Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Northern Hemisphere
x_values = north_hem_df["Latitude"]
y_values = north_hem_df["Wind Speed"]
plot_linear_regression(x_values,y_values,'Wind Speed',(6,30))

plt.savefig("N-Wind VS Lat LR")
# Out:
# The r-squared is: 0.11603062727295893

# %%
# Southern Hemisphere
x_values = south_hem_df["Latitude"]
y_values = south_hem_df["Wind Speed"]
plot_linear_regression(x_values,y_values,'Wind Speed',(6,30))

plt.savefig("S-Wind VS Lat LR")

print("The low r values indicate that there is no real relationship between wind speed and latitude. The difference between the hemispheres doesn't seem to be significant enough to comment upon.")
# Out:
# The r-squared is: -0.3245653756862875
# The low r values indicate that there is no real relationship between wind speed and latitude. The difference between the hemispheres doesn't seem to be significant enough to comment upon.

# %% [markdown]
# The low r values indicate that there is no real relationship between wind speed and latitude." The difference between the hemispheres doesn't seem to be significant enough to comment upon.
